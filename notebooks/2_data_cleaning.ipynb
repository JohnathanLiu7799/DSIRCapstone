# %% [markdown]
# ## Imports

# %%
import riotwatcher
import time
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/match_df.csv')

# %%
df.head()
# Out:
#          MATCH_ID  index                                          companion  \
# 0  NA1_4176715537      0  {'content_ID': 'b62511df-684d-4ff5-ad59-d3c557...
# 1  NA1_4176715537      1  {'content_ID': '390e34e6-4f74-474e-b079-62ba67...
# 2  NA1_4176715537      2  {'content_ID': '47f90ee9-181d-4085-a717-f8f5a1...
# 3  NA1_4176715537      3  {'content_ID': 'c3edfd17-cb97-49c3-b880-9a38dd...
# 4  NA1_4176715537      4  {'content_ID': '969b1b5f-3e5d-44fd-bfa3-1aa798...
#
#    gold_left  last_round  level  partner_group_id  placement  \
# 0          1          38      8               1.0          4
# 1          0          38      9               1.0          3
# 2          1          33      7               2.0          8
# 3          2          33      9               2.0          7
# 4          2          38      8               3.0          2
#
#    players_eliminated                                              puuid  \
# ...
